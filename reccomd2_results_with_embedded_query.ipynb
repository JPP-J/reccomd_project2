# %% [markdown]
# <a href="https://colab.research.google.com/github/JPP-J/reccomd_project2/blob/main/reccomd2_results_with_embedded_query.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Example result
# recommendations of movie dataset with different algorithms and last one is recommendations integrate with query keywords for user_id with 'all-MiniLM-L6-v2' model to embedded query to search from movie anme and genre.
#
#   > main.py
#
#           movieId  ...                           genres
#     9737   193581  ...  Action|Animation|Comedy|Fantasy
#     9738   193583  ...         Animation|Comedy|Fantasy
#     9739   193585  ...                            Drama
#     9740   193587  ...                 Action|Animation
#     9741   193609  ...                           Comedy
#
#     [5 rows x 3 columns]
#     Index(['movieId', 'title', 'genres'], dtype='object')
#     Original data shape: (100836, 3)
#     Columns: ['user_id' 'item_id' 'rating']
#     Sampling data shape: (100836, 3)
#
#     Generating recommendations for user_id: 325
#
#     User-based CF recommendations: [1733, 2075, 6184, 53, 99, 148, 467, 484, 495, 496]
#     Item-based CF recommendations: [791, 1116, 1137, 1144, 2566, 2623, 3106, 3899, 3912, 6125]
#     User KNN recommendations: [260, 1089, 1278, 912, 1097, 2571, 1220, 1617, 1240, 1208]
#     Item KNN recommendations: [750, 921, 1186, 1252, 21, 78, 223, 299, 373, 757]
#     Recommendations for user 325 with query 'drama Thriller': [1733, 2075, 180497, 6184, 53, 46723, 99, 148, 143365, 467]

# %% [markdown]
# Popular Models:
# 1. all-MiniLM-L6-v2:
#   - A lightweight and fast model with 384-dimensional embeddings.
#   -  Good balance between performance and speed.
# 2. all-mpnet-base-v2:
#   - A high-performance model with 768-dimensional embeddings.
#   - Provides better accuracy than all-MiniLM-L6-v2 but is slower.
# 3. paraphrase-MiniLM-L6-v2:
#   - Optimized for paraphrase detection and semantic similarity.
#   - 384-dimensional embeddings.
# 4. multi-qa-MiniLM-L6-cos-v1:
#   - Fine-tuned for question-answering and semantic search tasks.
#   -  384-dimensional embeddings.

# %% [markdown]
# # Example result testing
# query with random user_id on app.py with flask
#
# query example :  http://127.0.0.1:5000/recommend?query=comedy

# %% [markdown]
# Example1

# %% [markdown]
# ![{A96FC2ED-A2DE-4C6E-9C14-27C008F00FB5}.png](data:image/png;base64,...)

# %% [markdown]
# As above example recommend movie for user along with query input

# %% [markdown]
# ![{DE344486-4DE2-4164-82E2-A931A6CE1423}.png](data:image/png;base64,...)

# %% [markdown]
# Example2

# %% [markdown]
# ![{A4EF7426-4ED8-4331-A87B-F4152740A333}.png](data:image/png;base64,...)

# %% [markdown]
# ![{3D535736-CF84-4A4E-B772-C79CB9F366A0}.png](data:image/png;base64,...)
